# %%
import numpy as np

# %%
#  minimize f(x) = x^2)
def objective_function(x):
    return x**2

# %%
def clonal_selection_algorithm(population_size, num_clones, mutation_rate, num_generations, search_space):
    # Initialize population
    population = np.random.uniform(search_space[0], search_space[1], population_size)
    
    for generation in range(num_generations):
        # Evaluate fitness
        fitness = np.array([objective_function(x) for x in population])
        
        # Select best antibodies
        sorted_indices = np.argsort(fitness)
        selected_antibodies = population[sorted_indices[:num_clones]]
        
        # Clone and mutate
        clones = np.repeat(selected_antibodies, num_clones)
        mutations = np.random.normal(0, mutation_rate, clones.shape)
        clones = clones + mutations
        clones = np.clip(clones, search_space[0], search_space[1])  # Ensure clones stay within search space
        
        # Replace population
        population = np.concatenate((clones, np.random.uniform(search_space[0], search_space[1], population_size - num_clones)))
        
        # Track best solution
        best_fitness = np.min(fitness)
        best_solution = population[np.argmin(fitness)]
        print(f"Generation {generation + 1}: Best Fitness = {best_fitness}, Best Solution = {best_solution}")
    
    return best_solution, best_fitness

# %%
# Parameters
population_size = 20
num_clones = 5
mutation_rate = 0.1
num_generations = 50
search_space = (-10, 10)  # Define the search space for x

# %%
best_solution, best_fitness = clonal_selection_algorithm(population_size, num_clones, mutation_rate, num_generations, search_space)
print("\nFinal Result:")
print(f"Best Solution: {best_solution}")
print(f"Best Fitness: {best_fitness}")
# Out:
# Generation 1: Best Fitness = 0.00042857993825117766, Best Solution = -0.27525466730123616
# Generation 2: Best Fitness = 0.00017460373759771344, Best Solution = -0.009069215695295802
# Generation 3: Best Fitness = 3.907953237820131e-05, Best Solution = 0.08018070565708703
# Generation 4: Best Fitness = 1.0457047776732178e-06, Best Solution = -0.10459669481573551
# Generation 5: Best Fitness = 5.005281010572577e-05, Best Solution = 0.006203407223782282
# Generation 6: Best Fitness = 5.069479787251054e-06, Best Solution = -0.12100275575722974
# Generation 7: Best Fitness = 8.152549578215854e-07, Best Solution = -0.007906915424833579
# Generation 8: Best Fitness = 1.0300632697930788e-06, Best Solution = -0.01154293106907217
# Generation 9: Best Fitness = 2.085933125670671e-05, Best Solution = -0.03568427932913524
# Generation 10: Best Fitness = 3.5614139993088413e-06, Best Solution = -0.056172647349833106
# Generation 11: Best Fitness = 3.2184111737104685e-05, Best Solution = -0.02252716573567981
# Generation 12: Best Fitness = 7.640058599472405e-05, Best Solution = 5.760782628278045
# Generation 13: Best Fitness = 8.060897787961813e-05, Best Solution = 0.1662118432326776
# Generation 14: Best Fitness = 7.940588209369251e-05, Best Solution = 0.05327681262456199
# Generation 15: Best Fitness = 1.6667082298170426e-05, Best Solution = 0.08460709452021668
# Generation 16: Best Fitness = 3.687734035491207e-05, Best Solution = -0.12270436870469954
# Generation 17: Best Fitness = 6.993885636910442e-06, Best Solution = -0.0796640738914164
# Generation 18: Best Fitness = 3.907461491849843e-05, Best Solution = 0.1139753827173637
